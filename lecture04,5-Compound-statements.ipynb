# %%
name = "Asma"

if name == "Abdul":
    print("My name is Asma")
else:
    print("My name is not Asma")
# Out:
# My name is not Asma

# %%
x=5

if x == 25/3:
    print("If block is executed!!")
else :
    print("Else Block is executed!!")
# Out:
# Else Block is executed!!

# %%
age = 68

if age >= 65:
    print("You are an old guy")
elif age >=18:
    print("You are an adult")
else:
    print("You are a kid")
# Out:
# You are an old guy

# %%
age = 68

if age == 18:
    print("You are an adult")
elif age >= 65:
    print("You are an old guy")
else:
    print("You are a kid")
# Out:
# You are an old guy

# %%
fruit = "Orange"

if fruit=="banana":
    print(".")
elif fruit=="mango":
    print("..")
elif fruit=="papaya":
    print("...")
elif fruit=="Orange":
    print("....")
else:
    print("...........")
# Out:
# ....

# %%
age = 27
if age <= 18:
    if age == 18:
        print("You are an adult")
    else:
        print("You are a kid")
else:
    print("You are mature now!!")
# Out:
# You are mature now!!

# %%
def absolute_value(x):
    """Compute abs(x)."""
    
    if x > 0:
        return x
    elif x == 0: 
        return 0 
    else:
        return -x

# %%
absolute_value(-5)
# Out:
# 5

# %%
absolute_value(8)
# Out:
# 8

# %%
absolute_value(0)
# Out:
# 0

# %%
absolute_value(-1)
# Out:
# 1

# %%
# See in the tutor

# %%
# Another way to write this: 
def absolute_value(x):
    """Compute abs(x)."""
    if not x < 0:
        return x
    else:
        return -x

# %%
def absolute_value(x):
    """Compute abs(x)."""
    if x>=0:
        return x
    else:
        return -x

# %%
# we can also nest ifs 
a = 1
b = 2

if a > 5:
    if b > 6: 
        print ("a is more than 5 and b is more than 6")
    else: 
        print ("a is more than 5 BUT b is not more than 6")    
        
else: 
    print ("a is not more than 5")

print ("done")
# Out:
# a is not more than 5
# done

# %%
help(dt)
# Out:
# Help on module datetime:
#
# NAME
#     datetime - Fast implementation of the datetime type.
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/datetime.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# CLASSES
#     builtins.object
#         date
#             datetime
#         time
#         timedelta
#         tzinfo
#             timezone
#
#     class date(builtins.object)
#      |  date(year, month, day) --> date object
#      |
#      |  Methods defined here:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __format__(...)
# ...

# %%
import datetime as dt
def is_weekday(day, month, year): 
    y=dt.datetime(year=year, month=month, day=day)
    print("y",y)
    print(y.weekday())
    i=y.weekday() < 5
    return i

# %%
if is_weekday(20, 6, 2024):
    print ("It's a weekday.")
else: 
    print ("Weekend!!")
# Out:
# y 2024-06-20 00:00:00
# 3
# It's a weekday.

# %% [markdown]
# ## Algorithm
#
# ### Square root!
#
# Back to our square root example! We can finally write code for our algo.

# %%
def sqrt(x, guess = 0.0):
    """It will calculate the square root of positive numbers only!!"""
    if x < 0: 
        return None 
    
    if good_enough(guess, x): 
        return guess 
    
    else: 
        new_guess = improve_guess(guess, x)  
        return sqrt(x, new_guess)

# %%
def good_enough(guess, x): 
    if abs(guess * guess - x) < 0.1: 
        return True
    else: 
        return False

# %%
def improve_guess(guess, x): 
    if guess < x: 
        return guess + 0.1 
    else: 
        return guess - 0.1

# %%
print (sqrt(4, 1.8))     # for the tutor, give stating guess as 1.8
# Out:
# 2.0

# %%
print (sqrt(-2))  # let's also handle this case in our function
# Out:
# None
